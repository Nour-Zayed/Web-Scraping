# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.yallakora.com/Match-Center/?date=10/6/2024#'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html_content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ar">
# <head>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/ykicons.woff2?ver=1" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-bold.woff2" rel="preload" type="font/woff2"/>
# <!-- Preloading -->
# <link as="style" crossorigin="" href="/Content/StyleOnLoad.css?ver=0.1" rel="preload"/>
# <!-- strat: Chartbeat-->
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>
# <!-- end: chartbeat-->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
# <!-- Download App Notification -->
# ...

# %%
championships = soup.find_all('div', class_='matchCard')
championships
# Out:
# [<div class="2906 matchCard matchesList">
#  <div class="title">
#  <a class="tourTitle" href="/epl/2906/tour-hp/%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#MC_MatcheDetails">
#  <div class="imgCntnr">
#  <img alt="لوجو" class="lazy" data-src="https://www.yallakora.com/pictures/Tourlogo/PremierLeague30-7-2018-14-34-0.png" enname="EPL" height="26" loading="lazy" src="https://www.yallakora.com/pictures/Tourlogo/PremierLeague30-7-2018-14-34-0.png" width="26"/>
#  </div>
#  <h2>
#                                          الدوري الإنجليزي
#                                      </h2>
#  </a>
#  <div class="links">
#  <a class="more" href="/epl/2906/tour-news/%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#Matches-newslisting" title="أخبار">أخبار</a>
# ...

# %%
len(championships)
# Out:
# 9

# %%
championships[0]
# Out:
# <div class="2906 matchCard matchesList">
# <div class="title">
# <a class="tourTitle" href="/epl/2906/tour-hp/%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#MC_MatcheDetails">
# <div class="imgCntnr">
# <img alt="لوجو" class="lazy" data-src="https://www.yallakora.com/pictures/Tourlogo/PremierLeague30-7-2018-14-34-0.png" enname="EPL" height="26" loading="lazy" src="https://www.yallakora.com/pictures/Tourlogo/PremierLeague30-7-2018-14-34-0.png" width="26"/>
# </div>
# <h2>
#                                         الدوري الإنجليزي
#                                     </h2>
# </a>
# <div class="links">
# <a class="more" href="/epl/2906/tour-news/%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#Matches-newslisting" title="أخبار">أخبار</a>
# ...

# %%
champion_name = championships[0].find('h2').text.strip()
champion_name
# Out:
# 'الدوري الإنجليزي'

# %%
championships[0].contents[1].find('h2').text.strip()
# Out:
# 'الدوري الإنجليزي'

# %%
for i in range(len(championships)):
    champion_name = championships[i].contents[1].find('h2').text.strip()
    print(champion_name)
# Out:
# الدوري الإنجليزي
# الدوري الإسباني
# الدوري الألماني
# الدوري الفرنسي
# الدوري الإيطالي
# الدوري التركي
# الدوري البرتغالي
# الدوري المغربي
# الدوري الإماراتي

# %%
matches = championships[0].contents[3].find_all('div', class_='teamsData')
matches
# Out:
# [<div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="تشيلسي     " class="lazy" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Chelsea2018_7_29_15_28.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Chelsea2018_7_29_15_28.jpg" width="24"/>
#  <p>تشيلسي     </p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score">1</span>
#  <span>-</span>
#  <span class="score">1</span>
#  <span class="time">16:00</span>
#  </div>
#  <!-- Team B -->
#  <div class="teams teamB">
# ...

# %%
len(matches)
# Out:
# 3

# %%
matches[2].contents[3].find('p').text.strip()
# Out:
# 'برايتون'

# %%
matches[2].find_all('span', class_='score')[1].text.strip()
# Out:
# '2'

# %%
for j in range(len(matches)):
    teamA = matches[j].find('div', {'class':'teamA'}).text.strip()
    teamB = matches[j].find('div', class_='teamB').text.strip()
    scoreA = matches[j].find_all('span', class_='score')[0].text.strip()
    scoreB = matches[j].find_all('span', class_='score')[1].text.strip()
    time = matches[j].find('span', class_='time').text.strip()

    print(f'{teamA} {scoreA} - {scoreB} {teamB} \n\t\t {time}')
# Out:
# تشيلسي 1 - 1 نوتينجهام فورست
# 		 16:00
# أستون فيلا 0 - 0 مانشستر يونايتد
# 		 16:00
# برايتون 3 - 2 توتنهام هوتسبر
# 		 18:30

# %%
championships = soup.find_all('div', class_='matchCard')

for i in range(len(championships)):
    champion_name = championships[i].contents[1].find('h2').text.strip()
    # print(champion_name)
    f = open('matches.txt', 'a', encoding='utf-8')
    f.write(champion_name + '\n')

    matches = championships[i].contents[3].find_all('div', class_='teamsData')
    for j in range(len(matches)):
        teamA = matches[j].find('div', {'class':'teamA'}).text.strip()
        teamB = matches[j].find('div', class_='teamB').text.strip()
        scoreA = matches[j].find_all('span', class_='score')[0].text.strip()
        scoreB = matches[j].find_all('span', class_='score')[1].text.strip()
        time = matches[j].find('span', class_='time').text.strip()
        f.write(f'{teamA} {scoreA} - {scoreB} {teamB} \n\t\t {time}')
        f.write('\n')
    f.write('==================================')
    f.write('\n')
    f.close()

# %%
for j in range(len(matches)):
    teamA = matches[j].find('div', {'class':'teamA'}).text.strip()
    teamB = matches[j].find('div', class_='teamB').text.strip()
    scoreA = matches[j].find_all('span', class_='score')[0].text.strip()
    scoreB = matches[j].find_all('span', class_='score')[1].text.strip()
    time = matches[j].find('span', class_='time').text.strip()

    print(f'{teamA} {scoreA} - {scoreB} {teamB} \n\t\t {time}')
# Out:
# بني ياس 1 - 5 شباب الأهلي
# 		 16:10
# العين 1 - 2 الوحـــدة
# 		 18:45
# الشــارقة 2 - 1 العروبة
# 		 18:45
